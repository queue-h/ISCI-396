# %%
print("Hello World")
# Out:
# Hello World

# %%
def mars():
    print("Hello Mars")
mars()
# Out:
# Hello Mars

# %%
def if_jupiter(bool):
    if bool is True:
        print("Hello Jupiter")
    else:
        print("Hello Io")
if_jupiter(True)
if_jupiter(False)
# Out:
# Hello Jupiter
# Hello Io
